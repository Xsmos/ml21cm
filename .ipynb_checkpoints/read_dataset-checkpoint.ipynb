# %%
import py21cmfast as p21c
from py21cmfast import plotting
import os
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib import cm
import numpy as np
from scipy.spatial.transform import Rotation
from astropy import units as un
# %matplotlib inline


print(f"21cmFAST version is {p21c.__version__}")
user_params = p21c.UserParams(
    HII_DIM=256, BOX_LEN=512,
    NON_CUBIC_FACTOR = 2,
)

lightcone = p21c.run_lightcone(
    redshift = 7.51,
    max_redshift = 11.93,
    # global_quantities=("brightness_temp", 'density', 'xH_box'),
    direc='_backup',
    user_params=user_params,
    random_seed = 1,
)
# Out:
# 21cmFAST version is 3.3.1

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6), constrained_layout=True)
plotting.lightcone_sliceplot(lightcone, ax=ax, fig=fig, zticks='distance');

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6), constrained_layout=True)
plotting.lightcone_sliceplot(lightcone, ax=ax, fig=fig, zticks='distance');

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6), constrained_layout=True)
plotting.lightcone_sliceplot(lightcone, ax=ax, fig=fig, zticks='distance');

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6), constrained_layout=True)
plotting.lightcone_sliceplot(lightcone, ax=ax, fig=fig, zticks='distance');

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6), constrained_layout=True)
plotting.lightcone_sliceplot(lightcone, ax=ax, fig=fig, zticks='distance');

# %%
lightcone.lightcone_distances[-1] - lightcone.lightcone_distances[0]
# Out:
# 1028.0

# %%
lightcone.lightcone_distances.shape
# Out:
# (514,)

# %%
lightcone.shape
# Out:
# (256, 256, 514)

# %%
import numpy as np
import h5py
import os
import matplotlib.pyplot as plt

filename = '/storage/home/hcoda1/3/bxia34/scratch/train.h5'
with h5py.File(filename, 'r') as f:
    print(f.keys())
    brightness_temp = np.array(f['brightness_temp'])
    print("brightness_temp.shape =", brightness_temp.shape)
    print(f['kwargs'])
    kwargs = np.array(list(f['kwargs']))
    print("kwargs =")
    print(kwargs)
    print(f['params_seeds'])
    params_keys = list(f['params_seeds']['keys'])
    print("params.keys =", params_keys)
    params_values = np.array(list(f['params_seeds']['values']))
    seeds = params_values[:,-1]
    print("params.values =")
    print(params_values[:10,:])
    print(np.round(params_values[:10, -1]))
# Out:
# Failed to start the Kernel.
#
# Command "python setup.py egg_info" failed with error code 1 in /scratch/5234452/pip-build-92849wqz/argon2-cffi-bindings/.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
np.unique(seeds).shape

# %%
plt.scatter(params_values[:,0], params_values[:,1])
plt.xlabel(params_keys[0])
plt.ylabel(params_keys[1])
plt.title("Latin hypercube sampling")
plt.show()

# %%
if __name__ == '__main__':
    fig, axes = plt.subplots(4,8, figsize=(24,12),dpi=300)
    for i, ax in enumerate(axes.flat):
        ax.imshow(brightness_temp[i][1][0])
        ax.set_xlabel('')
        ax.set_ylabel('')
        ax.axis('off')
        ax.set_title(params_values[i][2])
    # plt.margins(x=0, y=0)
    # plt.suptitle(params_keys)
    plt.tight_layout(w_pad=0.2)
    # plt.close()

# %%
import numpy as np
import h5py
import os
import matplotlib.pyplot as plt

filename = '/storage/home/hcoda1/3/bxia34/scratch/test.h5'
with h5py.File(filename, 'r') as f:
    print(f.keys())
    brightness_temp = np.array(f['brightness_temp'])
    print("brightness_temp.shape =", brightness_temp.shape)
    density = np.array(f['density'])
    print("density.shape =", density.shape)
    print(f['kwargs'])
    kwargs = np.array(list(f['kwargs']))
    print("kwargs =")
    print(kwargs)
    print(f['params_seeds'])
    params_keys = list(f['params_seeds']['keys'])
    print("params.keys =", params_keys)
    params_values = np.array(list(f['params_seeds']['values']))
    seeds = params_values[:,-1]
    print("params.values =")
    print(params_values[:10,:])

# %%
np.unique(seeds).shape

# %%
plt.scatter(params_values[:,0], params_values[:,1])
plt.xlabel(params_keys[0])
plt.ylabel(params_keys[1])
plt.title("Each point corresponds to 16 different initial conditions")
plt.show()

# %%
if __name__ == '__main__':
    fig, axes = plt.subplots(16,1, figsize=(32,8),dpi=300)
    for i, ax in enumerate(axes.flat):
        ax.imshow(brightness_temp[2*i][0])
        ax.set_xlabel('')
        ax.set_ylabel('')
        ax.axis('off')
        # ax.set_title(params_values[2*i][:2])
    # plt.margins(x=0, y=0)
    # plt.suptitle(list(params_ranges.keys()))
    plt.suptitle(params_keys[:2])
    plt.tight_layout(w_pad=0.2, h_pad=0.1)
    # plt.close()

# %%
if __name__ == '__main__':
    fig, axes = plt.subplots(16,1, figsize=(32,8),dpi=300)
    for i, ax in enumerate(axes.flat):
        ax.imshow(density[2*i][0])
        ax.set_xlabel('')
        ax.set_ylabel('')
        ax.axis('off')
        # ax.set_title(params_values[2*i][:2])
    # plt.margins(x=0, y=0)
    plt.suptitle(params_keys[:2])
    plt.tight_layout(w_pad=0.2, h_pad=0.1)
    # plt.close()
