# %%
import os, sys

parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
print(f"sys.path.append(parent_dir): {parent_dir}")
sys.path.append(parent_dir)

from utils.load_h5 import Dataset4h5, ranges_dict
from utils.plot_mp4 import plot_mp4
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.patches import Patch
from matplotlib.legend_handler import HandlerBase
from matplotlib.legend_handler import HandlerTuple

import numpy as np
from torch.utils.data import DataLoader
import h5py
import matplotlib as mpl
from scipy.fftpack import fft, fftshift, ifft
from scipy.fftpack import fftfreq
from scipy.linalg import sqrtm

import torch
from matplotlib.lines import Line2D
from kymatio.torch import Scattering2D

from scipy.interpolate import interp1d
import joblib
from tqdm import tqdm
import gc

import multiprocessing
import matplotlib.ticker as ticker
from cycler import cycler

from numpy import interp
from matplotlib.ticker import FuncFormatter
import matplotlib
from typing import List
import argparse

import os

multiprocessing.set_start_method('spawn', force=True)

gridspec_kw = {'height_ratios': [3,1,1,1]}
# Global typography defaults for clearer figures
plt.rcParams.update({
    'font.size': 14,
    'axes.titlesize': 20,
    'axes.labelsize': 17,
    'xtick.labelsize': 11,
    'ytick.labelsize': 11,
    'legend.fontsize': 13,
    'legend.title_fontsize': 13,
    'figure.titlesize': 20,
})
# Out:
# sys.path.append(parent_dir): /pscratch/sd/b/binxia/ml21cm

# %%
def labelize(param):
    param = param.tolist()
    param[0] = round(param[0], 1)
    param[1] = int(round(param[1], 0))
    label = r"$(\log_{10}T_{\rm vir},\zeta)=$" + f"{tuple(param)}"
    return label

# %%
def load_h5_as_tensor(dir_name='LEN128-DIM64-CUB8.h5', num_image=256, num_redshift=1024, HII_DIM=64, z_step=1, scale_path=False, dim=3, startat=0, pt_fname=None, transform=False):
    dir_name = os.path.join(os.environ['SCRATCH'], dir_name)
    dataset = Dataset4h5(dir_name, num_image=num_image, num_redshift=num_redshift, HII_DIM=HII_DIM, z_step=z_step, scale_path=scale_path, dim=dim, startat=startat)

    with h5py.File(dir_name) as f:
        los = f['redshifts_distances'][:,startat:startat+dataset.num_redshift:z_step]

    dataloader = DataLoader(dataset, batch_size=800)
    
    x, c = next(iter(dataloader))

    if 'pt' == transform and (pt_fname is not None):
        original_shape = x.shape
        pt = joblib.load(pt_fname)
        x = pt.transform(x.reshape(-1, 1))
        x = torch.from_numpy(x.reshape(*original_shape))

    return x, c, los

os.environ["SLURM_NODEID"] = '0'

# %%
def get_eor_cmap(vmin=-150, vmax=30):
    name = f"EoR-{vmin}-{vmax}"

    EoR_colour = matplotlib.colors.LinearSegmentedColormap.from_list(
        name,
        [
            (0, 'white'),
            (0.33, 'yellow'),
            (0.5, 'orange'),
            (0.68, 'red'),
            (0.83333333, 'black'),
            (0.9, 'blue'),
            (1, 'cyan')])
    
    try:
        matplotlib.colormaps.register(cmap=EoR_colour)
    except ValueError:
        matplotlib.colormaps.unregister(name)
        matplotlib.colormaps.register(cmap=EoR_colour)

    return name

vmin = -150
vmax = 30
cmap = get_eor_cmap(vmin, vmax)


def calc_ps(field, L):
    ng = field.shape[0]
    ndim = field.ndim

    ru = np.fft.fftn(field)
    ru *= (L / ng) ** ndim

    if ndim == 3:
        ru = ru[0:ng//2+1, 0:ng//2+1, 0:ng//2+1]
    elif ndim == 2:
        ru = ru[0:ng//2+1, 0:ng//2+1]
    else:
        raise ValueError(f"Unsupported field.ndim={ndim}")

    ru = np.abs(ru) ** 2

    # Use cycles/Mpc only for stable Fourier-mode binning.
    kx_cyc = np.fft.rfftfreq(ng) * ng / L
    ky_cyc = kx_cyc.copy()
    kz_cyc = kx_cyc.copy()

    kmin_cyc = 1 / L
    kmax_cyc = 0.5 * ng / L

    kbins_cyc = np.arange(kmin_cyc, kmax_cyc, kmin_cyc)

    if ndim == 3:
        k_nd_cyc = np.meshgrid(kx_cyc, ky_cyc, kz_cyc, indexing="ij")
    elif ndim == 2:
        k_nd_cyc = np.meshgrid(kx_cyc, ky_cyc, indexing="ij")

    k_cyc = np.sqrt(np.sum(np.array(k_nd_cyc) ** 2, axis=0))

    P_raw = np.array([
        np.mean(ru[(k_cyc >= kbins_cyc[i]) & (k_cyc < kbins_cyc[i + 1])])
        for i in range(len(kbins_cyc) - 1)
    ])

    kcen_cyc = 0.5 * (kbins_cyc[:-1] + kbins_cyc[1:])

    # Convert the reported bin centers to angular wavenumber.
    kcen = 2 * np.pi * kcen_cyc

    # Compute dimensionless power using angular k.
    if ndim == 3:
        Delta2 = P_raw * (kcen ** 3) / (2 * np.pi ** 2)
    elif ndim == 2:
        Delta2 = P_raw * (kcen ** 2) / (2 * np.pi)

    return kcen, Delta2

def x2Pk(x, z_idx=0):
    print(f"x2Pk, x.shape = {x.shape}")
    Pk_vals_all = []
    for i in range(x.shape[0]):
        if x.ndim == 4:
            density_field = x[i,0,:,z_idx:z_idx+x.shape[-2]]
        elif x.ndim == 5:
            # density_field = x[i,0,...,z_idx]
            density_field = x[i,0,0,:,z_idx:z_idx+x.shape[-2]]
        if density_field.ndim == 3:
            Nx, Ny, Nz = density_field.shape
            box_size = 128#(128.0, 128.0, 1024.0) #512#
        elif density_field.ndim == 2:
            Nx, Ny = density_field.shape
            box_size = 128#(128.0, 1024.0) #512#

        k_vals, Pk_vals = calc_ps(density_field, box_size)

        # k_vals_all.append(k_vals)
        Pk_vals_all.append(Pk_vals)

    Pk_vals_all = np.array(Pk_vals_all)
    return k_vals, Pk_vals_all

    
def x2Tb(x):
    #print('x.shape =', x.shape, 'x.ndim =', x.ndim)
    if x.ndim == 4:
        Tb = x[:,0].mean(axis=1)
    elif x.ndim == 5:
        Tb = x[:,0].mean(axis=(1,2))
    return Tb

# %%
def load_x_ml(fname_pattern0, fname_pattern1, ema = 0, outputs_dir = "../training/outputs", pt_fname=None, transform=False):
    # num = 7200
    x_ml = []
    fnames = [fname for fname in os.listdir(outputs_dir) if fname_pattern0 in fname and fname_pattern1 in fname and f'-ema{ema}.npy' in fname]
    if len(fnames) == 0:
        raise ValueError(f"No files found with patterns: {fname_pattern0}, {fname_pattern1} in {outputs_dir}")
    else:
        print("fname pattern:", fname_pattern0, fname_pattern1, "; len(fnames) =", len(fnames), ";\nfnames[0] =", fnames[0])

    for fname in fnames:
        data = np.load(os.path.join(outputs_dir, fname))
        x_ml.append(data)

        # if len(x_ml) > 20:
        #     print(f"🆘 Warning: More than 100 files found for patterns {fname_pattern0}, {fname_pattern1}. Only the first 100 will be loaded.")
        #     break

    x_ml = np.concatenate(x_ml, axis=0)
    original_shape = x_ml.shape

    if 'pt_inv' == transform and (pt_fname is not None):
        pt = joblib.load(pt_fname)
        x_ml = pt.inverse_transform(x_ml.reshape(-1, 1))
    elif 'min_max' == transform:
        min_val, max_val = ranges_dict[transform]
        x_ml = (x_ml + 1) / 2
        x_ml = x_ml * (max_val - min_val) + min_val
    elif 'z_score' == transform:
        mean_val, std_val = ranges_dict[transform]
        x_ml = x_ml * std_val + mean_val
    elif 'arcsinh' == transform:
        # inverse arcsinh
        x_ml = np.sinh(x_ml)

    x_ml = torch.from_numpy(x_ml.reshape(*original_shape))
    print(f"loaded x_ml.shape = {x_ml.shape}")
    return x_ml

def load_x_ml_entire(fname_pattern0, fname_pattern1, ema = 0, outputs_dir = "../training/outputs", pt_fname=None, transform=False):
    # num = 7200
    x_ml = []
    fnames = [fname for fname in os.listdir(outputs_dir) if fname_pattern0 in fname and fname_pattern1 in fname and f'-ema{ema}_entire.h5' in fname]
    if len(fnames) == 0:
        raise ValueError(f"No files found with patterns: {fname_pattern0}, {fname_pattern1} in {outputs_dir}")
    else:
        print("fname pattern:", fname_pattern0, fname_pattern1, "; len(fnames) =", len(fnames), ";\nfnames[0] =", fnames[0])

    print(f"{fnames=}")
    for fname in fnames:
        # data = np.load(os.path.join(outputs_dir, fname))
        with h5py.File(os.path.join(outputs_dir, fname), "r") as f:
            data = f["denoising_trajectory"][:,:,:,0,:,:]
            print(f"⚠️ {data.shape=}")
            
        x_ml.append(data)

    x_ml = np.concatenate(x_ml, axis=1)
    original_shape = x_ml.shape

    if 'pt_inv' == transform and (pt_fname is not None):
        pt = joblib.load(pt_fname)
        x_ml = pt.inverse_transform(x_ml.reshape(-1, 1))
    elif 'min_max' == transform:
        min_val, max_val = ranges_dict[transform]
        x_ml = (x_ml + 1) / 2
        x_ml = x_ml * (max_val - min_val) + min_val
    elif 'z_score' == transform:
        mean_val, std_val = ranges_dict[transform]
        x_ml = x_ml * std_val + mean_val
    elif 'arcsinh' == transform:
        # inverse arcsinh
        x_ml = np.sinh(x_ml)

    x_ml = torch.from_numpy(x_ml.reshape(*original_shape))
    print(f"loaded x_ml_entire.shape = {x_ml.shape}")
    return x_ml

# %%
class HandlerRectLine(HandlerBase):
    def create_artists(self, legend, orig_handle, x0, y0, width, height, fontsize, trans):
        rect = Rectangle(
            (x0, y0),
            width,
            height,
            facecolor=orig_handle.get('rect_fc', 'black'),
            edgecolor=orig_handle.get('rect_ec', 'black'),
            linewidth=orig_handle.get('rect_lw', 0.8),
            alpha=orig_handle.get('rect_alpha', 0.3),
            transform=trans
        )

        line = Line2D(
            [x0, x0 + width],
            [y0 + height / 2, y0 + height / 2],
            color=orig_handle.get('line_color', 'black'),
            linestyle=orig_handle.get('line_ls', ':'),
            linewidth=orig_handle.get('line_lw', 1.5),
            alpha=orig_handle.get('line_alpha', 1.0),
            transform=trans
        )

        return [rect, line]

# %%
def add_lower_legend(
    ax_i,
    eps_all_i,
    eps_label,
    model_labels,
    summary_colors,
    model_linestyles,
    model_fill_alphas,
    model_line_alphas,
    plot_lw,
    edge_kwargs_func=None,
    fmt=".1f",
    show_handles=False,
    loc="center left",
    fontsize=9,
):
    handles = []
    labels = []

    n_models = len(model_labels)

    for j in range(n_models):

        mae = np.nanmean(np.abs(np.array(eps_all_i[j])))

        labels.append(
            f"{model_labels[j]} "
            + eps_label
            + f"={mae:{fmt}}"
        )

        if show_handles:
            color_j = summary_colors[j % len(summary_colors)]
            linestyle_j = model_linestyles[j % len(model_linestyles)]

            if edge_kwargs_func is None:
                edgecolor_j, linewidth_j = "none", 0
            else:
                edgecolor_j, linewidth_j = edge_kwargs_func(j)

            handles.append({
                'rect_fc': color_j,
                'rect_ec': edgecolor_j,
                'rect_lw': linewidth_j,
                'rect_alpha': model_fill_alphas[j],
                'line_color': color_j,
                'line_ls': linestyle_j,
                'line_lw': plot_lw,
                'line_alpha': model_line_alphas[j],
            })

        else:
            handles.append(Line2D([], [], linestyle='none'))

    if show_handles:
        ax_i.legend(
            handles,
            labels,
            handler_map={dict: HandlerRectLine()},
            fontsize=fontsize,
            loc=loc,
            frameon=True,
        )
    else:
        ax_i.legend(
            handles,
            labels,
            fontsize=fontsize,
            loc=loc,
            frameon=True,
            handlelength=0,
            handletextpad=0,
        )

# %%
def plot_global_signal(
    x_pairs,
    params,
    los,
    sigma_level=68.27,
    alpha=0.2,
    lw=0.6,
    y_eps=1,
    savename=None,
    z_idx=None,
    model_labels=None,
    num_x_pairs_in_first_panel=5,
):

    low = (100 - sigma_level) / 2
    high = 100 - low

    fig, ax = plt.subplots(
        4, 1,
        sharex=True,
        figsize=(8, 6),
        dpi=200,
        gridspec_kw=gridspec_kw
    )

    line_lw = lw + 1
    plot_lw = plt.rcParams.get("lines.linewidth", 1.5)

    model_linestyles = [':', '--', '-.', (0, (3, 1, 1, 1, 1, 1))]
    summary_colors = ['grey', 'black', '#8C8C8C', '#9C6B98', '#5F6B6D', '#A89F68']

    n_models = None
    dist_ref = None

    eps_rel_all = None
    eps_std_all = None
    eps_sigma_all = None

    model_fill_alphas = None
    model_line_alphas = None

    def _use_edge_for_model(j):
        return "2D" in model_labels[j]

    def _edge_kwargs(j):
        if _use_edge_for_model(j):
            return "black", 1
        else:
            return "none", 0

    # =======================
    # loop over parameter points
    # =======================
    for i, (x0, x1) in enumerate(x_pairs):

        x1_list = x1 if isinstance(x1, (list, tuple)) else [x1]

        if n_models is None:
            n_models = len(x1_list)

            if model_labels is None:
                model_labels = [f"model {j}" for j in range(n_models)]

            if len(model_labels) != n_models:
                raise ValueError("model_labels must have the same length as the model list.")

            eps_rel_all = [[] for _ in range(n_models)]
            eps_std_all = [[] for _ in range(n_models)]
            eps_sigma_all = [[] for _ in range(n_models)]

            if n_models == 1:
                model_fill_alphas = [alpha]
                model_line_alphas = [1.0]
            else:
                model_fill_alphas = np.linspace(alpha * 0.65, alpha * 1.35, n_models)
                model_line_alphas = np.linspace(0.6, 1.0, n_models)

        elif len(x1_list) != n_models:
            raise ValueError("Each x_pair must contain the same number of model outputs.")

        # -----------------------
        # 21cmFAST
        # -----------------------
        Tb0 = x2Tb(x0)

        y0 = np.median(Tb0, axis=0)
        Tb0_perc = np.percentile(Tb0, [low, high], axis=0)

        n_los = y0.shape[-1]
        dist = los[1, :n_los]

        if dist_ref is None:
            dist_ref = dist
        else:
            if len(dist) != len(dist_ref) or not np.allclose(dist, dist_ref):
                raise ValueError("distance axis is inconsistent across parameter points.")

        sigma0_lower = y0 - Tb0_perc[0]
        sigma0_upper = Tb0_perc[1] - y0
        sigma0 = 0.5 * (Tb0_perc[1] - Tb0_perc[0])

        color_i = f"C{i}"
        interval = max(1, n_los // 73)

        # Top panel: 21cmFAST = solid median + 1 sigma errorbar
        if i < num_x_pairs_in_first_panel:
            ax[0].plot(
                dist,
                y0,
                linestyle='-',
                color=color_i,
                lw=plot_lw,
                alpha=0.95,
            )

            ax[0].errorbar(
                dist[::interval],
                y0[::interval],
                yerr=[sigma0_lower[::interval], sigma0_upper[::interval]],
                fmt='none',
                color=color_i,
                elinewidth=1.0,
                capsize=0,
                alpha=0.95,
            )

        # -----------------------
        # diffusion models
        # -----------------------
        for j, x1_j in enumerate(x1_list):

            Tb1 = x2Tb(x1_j)

            y1 = np.median(Tb1, axis=0)
            Tb1_perc = np.percentile(Tb1, [low, high], axis=0)
            sigma1 = 0.5 * (Tb1_perc[1] - Tb1_perc[0])

            linestyle_j = model_linestyles[j % len(model_linestyles)]
            edgecolor_j, linewidth_j = _edge_kwargs(j)

            # Top panel: diffusion = median line + shaded spread
            if i < num_x_pairs_in_first_panel:
                ax[0].fill_between(
                    dist,
                    Tb1_perc[0],
                    Tb1_perc[1],
                    color=color_i,
                    alpha=model_fill_alphas[j],
                    edgecolor=edgecolor_j,
                    linewidth=linewidth_j,
                )

                ax[0].plot(
                    dist,
                    y1,
                    linestyle=linestyle_j,
                    color=color_i,
                    lw=plot_lw,
                    alpha=model_line_alphas[j],
                )

            # -----------------------
            # errors relative to 21cmFAST
            # -----------------------
            eps_rel_full = np.full_like(y0, np.nan, dtype=float)
            eps_std_full = np.full_like(y0, np.nan, dtype=float)
            eps_sigma_full = np.full_like(y0, np.nan, dtype=float)

            mask_rel = np.abs(y0) > y_eps
            mask_std = sigma0 > y_eps

            eps_rel_full[mask_rel] = (
                (y1[mask_rel] - y0[mask_rel]) / np.abs(y0[mask_rel])
            )

            eps_std_full[mask_std] = (
                (y1[mask_std] - y0[mask_std]) / sigma0[mask_std]
            )

            eps_sigma_full[mask_std] = (
                sigma1[mask_std] / sigma0[mask_std] - 1.0
            )

            eps_rel_all[j].append(eps_rel_full)
            eps_std_all[j].append(eps_std_full)
            eps_sigma_all[j].append(eps_sigma_full)

    dist = dist_ref

    # =======================
    # panel 1 formatting
    # =======================
    ax[0].set_ylabel(r'$\langle T_b \rangle$ [mK]')
    # ax[0].set_title(r"global signal of $T_b$")
    ax[0].grid()

    # -----------------------
    # legend for style meaning
    # -----------------------
    h_fast = ax[0].errorbar(
        [np.nan],
        [np.nan],
        yerr=[[0.2], [0.2]],
        fmt='-',
        color='black',
        lw=plot_lw,
        elinewidth=1.2,
        capsize=0,
    )

    style_handles = [h_fast]
    style_labels = ['21cmFAST median ± 1σ']

    for j in range(n_models):
        edgecolor_j, linewidth_j = _edge_kwargs(j)

        style_handles.append({
            'rect_fc': 'black',
            'rect_ec': edgecolor_j,
            'rect_lw': linewidth_j,
            'rect_alpha': model_fill_alphas[j],
            'line_color': 'black',
            'line_ls': model_linestyles[j % len(model_linestyles)],
            'line_lw': plot_lw,
            'line_alpha': model_line_alphas[j],
        })
        style_labels.append(model_labels[j] + ' median ± 1σ')

    legend1 = ax[0].legend(
        style_handles,
        style_labels,
        handler_map={dict: HandlerRectLine()},
        loc='upper left',
        fontsize=9,
        frameon=True,
    )
    ax[0].add_artist(legend1)

    # -----------------------
    # legend for parameter colors
    # -----------------------
    param_handles = [
        Line2D(
            [0], [0],
            color=f"C{i}",
            lw=plot_lw,
            label=labelize(params[i])
        )
        for i in range(num_x_pairs_in_first_panel)
    ]

    ax[0].legend(
        handles=param_handles,
        loc='lower left',
        fontsize=8,
        frameon=True,
    )

    # =======================
    # panels 2--4:
    # median + shaded region over parameter points
    # =======================
    for j in range(n_models):

        color_j = summary_colors[j % len(summary_colors)]
        linestyle_j = model_linestyles[j % len(model_linestyles)]
        edgecolor_j, linewidth_j = _edge_kwargs(j)

        eps_rel_j = np.array(eps_rel_all[j])
        eps_std_j = np.array(eps_std_all[j])
        eps_sigma_j = np.array(eps_sigma_all[j])

        # -----------------------
        # eps_rel
        # -----------------------
        eps_rel_med = np.nanmedian(eps_rel_j, axis=0)
        eps_rel_lo = np.nanpercentile(eps_rel_j, low, axis=0)
        eps_rel_hi = np.nanpercentile(eps_rel_j, high, axis=0)

        valid_rel = (
            np.isfinite(eps_rel_med)
            & np.isfinite(eps_rel_lo)
            & np.isfinite(eps_rel_hi)
        )

        ax[1].fill_between(
            dist[valid_rel],
            eps_rel_lo[valid_rel],
            eps_rel_hi[valid_rel],
            alpha=model_fill_alphas[j],
            color=color_j,
            edgecolor=edgecolor_j,
            linewidth=linewidth_j,
        )

        ax[1].plot(
            dist[valid_rel],
            eps_rel_med[valid_rel],
            color=color_j,
            linestyle=linestyle_j,
            lw=plot_lw,
            alpha=model_line_alphas[j],
        )

        # -----------------------
        # eps_std
        # -----------------------
        eps_std_med = np.nanmedian(eps_std_j, axis=0)
        eps_std_lo = np.nanpercentile(eps_std_j, low, axis=0)
        eps_std_hi = np.nanpercentile(eps_std_j, high, axis=0)

        valid_std = (
            np.isfinite(eps_std_med)
            & np.isfinite(eps_std_lo)
            & np.isfinite(eps_std_hi)
        )

        ax[2].fill_between(
            dist[valid_std],
            eps_std_lo[valid_std],
            eps_std_hi[valid_std],
            alpha=model_fill_alphas[j],
            color=color_j,
            edgecolor=edgecolor_j,
            linewidth=linewidth_j,
        )

        ax[2].plot(
            dist[valid_std],
            eps_std_med[valid_std],
            color=color_j,
            linestyle=linestyle_j,
            lw=plot_lw,
            alpha=model_line_alphas[j],
        )

        # -----------------------
        # eps_sigma
        # -----------------------
        eps_sigma_med = np.nanmedian(eps_sigma_j, axis=0)
        eps_sigma_lo = np.nanpercentile(eps_sigma_j, low, axis=0)
        eps_sigma_hi = np.nanpercentile(eps_sigma_j, high, axis=0)

        valid_sigma = (
            np.isfinite(eps_sigma_med)
            & np.isfinite(eps_sigma_lo)
            & np.isfinite(eps_sigma_hi)
        )

        ax[3].fill_between(
            dist[valid_sigma],
            eps_sigma_lo[valid_sigma],
            eps_sigma_hi[valid_sigma],
            alpha=model_fill_alphas[j],
            color=color_j,
            edgecolor=edgecolor_j,
            linewidth=linewidth_j,
        )

        ax[3].plot(
            dist[valid_sigma],
            eps_sigma_med[valid_sigma],
            color=color_j,
            linestyle=linestyle_j,
            lw=plot_lw,
            alpha=model_line_alphas[j],
        )

    # =======================
    # lower panel formatting
    # =======================
    ax[1].set_ylabel(r"$\epsilon_{\rm rel}$")
    ax[2].set_ylabel(r"$\epsilon_{\rm std}$")
    ax[3].set_ylabel(r"$\epsilon_{\sigma}$")

    ax[1].grid()
    ax[2].grid()
    ax[3].grid()

    add_lower_legend(
        ax[1],
        eps_rel_all,
        r"$\overline{|\epsilon_{\rm rel}|}$",
        model_labels,
        summary_colors,
        model_linestyles,
        model_fill_alphas,
        model_line_alphas,
        plot_lw,
        edge_kwargs_func=_edge_kwargs,
        fmt=".2f",
        show_handles=False,
    )
    
    add_lower_legend(
        ax[2],
        eps_std_all,
        r"$\overline{|\epsilon_{\rm std}|}$",
        model_labels,
        summary_colors,
        model_linestyles,
        model_fill_alphas,
        model_line_alphas,
        plot_lw,
        edge_kwargs_func=_edge_kwargs,
        fmt=".2f",
        show_handles=False,
    )
    
    add_lower_legend(
        ax[3],
        eps_sigma_all,
        r"$\overline{|\epsilon_{\sigma}|}$",
        model_labels,
        summary_colors,
        model_linestyles,
        model_fill_alphas,
        model_line_alphas,
        plot_lw,
        edge_kwargs_func=_edge_kwargs,
        fmt=".2f",
        show_handles=False,
    )

    ax[1].set_ylim(ymin=-.49, ymax=.49)
    ax[2].set_ylim(ymin=-.49, ymax=.49)
    ax[3].set_ylim(ymin=-.49, ymax=.49)

    ax[3].xaxis.set_major_formatter(FuncFormatter(lambda x, pos: f'{x / 1000:.1f}'))
    ax[3].set_xlabel('distance [Gpc]')

    # top redshift axis
    ax_twin = ax[0].secondary_xaxis('top')
    ax_twin.set_xlim(ax[0].get_xlim())
    ax_twin.set_xlabel('redshift')
    ax_twin.xaxis.set_major_locator(ticker.MaxNLocator(10))
    ax_twin.set_xticks(ax_twin.get_xticks())

    z_ticks = interp(ax_twin.get_xticks(), los[1], los[0])
    ax_twin.set_xticklabels([f"{ztick:.1f}" for ztick in z_ticks])
    ax_twin.spines['bottom'].set_position(('outward', 10))

    # blank upper x tick labels for lower panels
    ax1_sec = ax[1].secondary_xaxis("top")
    ax1_sec.set_xticklabels([])

    ax2_sec = ax[2].secondary_xaxis("top")
    ax2_sec.set_xticklabels([])

    ax3_sec = ax[3].secondary_xaxis("top")
    ax3_sec.set_xticklabels([])

    plt.subplots_adjust(hspace=0)

    if savename is None:
        plt.show()
    else:
        savename = f"global_Tb_{savename}_z{z_idx}.pdf"
        plt.savefig(savename, bbox_inches='tight')
        print(f'Image saved to {savename}')
        plt.close()

# %%
def plot_power_spectrum(
    x_pairs,
    params,
    los,
    sigma_level=68.27,
    alpha=0.2,
    z_idx=0,
    savename=None,
    y_eps=1,
    model_labels=None,
    num_x_pairs_in_first_panel=5,
):

    low = (100 - sigma_level) / 2
    high = 100 - low

    fig, ax = plt.subplots(
        4, 1,
        sharex=True,
        figsize=(8, 6),
        dpi=200,
        gridspec_kw=gridspec_kw
    )

    plot_lw = plt.rcParams.get("lines.linewidth", 1.5) #+ 1

    # Line styles distinguish different diffusion models.
    model_linestyles = [':', '--', '-.', (0, (3, 1, 1, 1, 1, 1))]

    # Colors for lower summary panels only.
    # These are independent from the top-panel parameter colors.
    # summary_colors = ['black', 'firebrick', 'saddlebrown', 'teal', 'darkmagenta', 'royalblue']
    summary_colors = ['grey', 'black', '#8C8C8C', '#9C6B98', '#5F6B6D', '#A89F68']

    n_models = None
    k_vals_ref = None

    eps_rel_all = None
    eps_std_all = None
    eps_sigma_all = None

    model_fill_alphas = None
    model_line_alphas = None

    def _use_edge_for_model(j):
        # Default: add black edge to 2D shaded region.
        # If your 2D model is not labeled with "2D", change this line.
        return "2D" in model_labels[j]

    def _edge_kwargs(j):
        if _use_edge_for_model(j):
            return "black", 1
        else:
            return "none", 0

    # =======================
    # loop over parameter points
    # =======================
    for i, (x0, x1) in enumerate(x_pairs):

        # x1 can be either x_ml or [x_ml2D, x_ml3D, ...]
        x1_list = x1 if isinstance(x1, (list, tuple)) else [x1]

        if n_models is None:
            n_models = len(x1_list)

            if model_labels is None:
                model_labels = [f"model {j}" for j in range(n_models)]

            if len(model_labels) != n_models:
                raise ValueError("model_labels must have the same length as the model list.")

            eps_rel_all = [[] for _ in range(n_models)]
            eps_std_all = [[] for _ in range(n_models)]
            eps_sigma_all = [[] for _ in range(n_models)]

            if n_models == 1:
                model_fill_alphas = [alpha]
                model_line_alphas = [1.0]
            else:
                model_fill_alphas = np.linspace(alpha * 0.65, alpha * 1.35, n_models)
                model_line_alphas = np.linspace(0.6, 1.0, n_models)

        elif len(x1_list) != n_models:
            raise ValueError("Each x_pair must contain the same number of model outputs.")

        # -----------------------
        # 21cmFAST
        # -----------------------
        k_vals, Pk0 = x2Pk(x0, z_idx=z_idx)

        if k_vals_ref is None:
            k_vals_ref = k_vals
        else:
            if len(k_vals) != len(k_vals_ref) or not np.allclose(k_vals, k_vals_ref):
                raise ValueError("k_vals are inconsistent across parameter points.")

        y0 = np.median(Pk0, axis=0)
        Pk0_perc = np.percentile(Pk0, [low, high], axis=0)

        sigma0_lower = y0 - Pk0_perc[0]
        sigma0_upper = Pk0_perc[1] - y0
        sigma0 = 0.5 * (Pk0_perc[1] - Pk0_perc[0])

        color_i = f"C{i}"

        # Top panel: parameter color.
        # 21cmFAST = median solid line + 1 sigma error bar.
        if i < num_x_pairs_in_first_panel:
            ax[0].errorbar(
                k_vals,
                y0,
                yerr=[sigma0_lower, sigma0_upper],
                linestyle='-',
                color=color_i,
                linewidth=plot_lw,
                elinewidth=1.0,
                capsize=0,
                alpha=0.95,
            )

        # -----------------------
        # diffusion models
        # -----------------------
        for j, x1_j in enumerate(x1_list):

            _, Pk1 = x2Pk(x1_j, z_idx=z_idx)

            y1 = np.median(Pk1, axis=0)
            Pk1_perc = np.percentile(Pk1, [low, high], axis=0)
            sigma1 = 0.5 * (Pk1_perc[1] - Pk1_perc[0])

            linestyle_j = model_linestyles[j % len(model_linestyles)]
            edgecolor_j, linewidth_j = _edge_kwargs(j)

            # Top panel: same parameter color.
            # Diffusion = median dashed/dash-dot line + shaded spread.
            if i < num_x_pairs_in_first_panel:
                ax[0].fill_between(
                    k_vals,
                    Pk1_perc[0],
                    Pk1_perc[1],
                    color=color_i,
                    alpha=model_fill_alphas[j],
                    edgecolor=edgecolor_j,
                    linewidth=linewidth_j,
                )
    
                ax[0].plot(
                    k_vals,
                    y1,
                    linestyle=linestyle_j,
                    color=color_i,
                    lw=plot_lw,
                    alpha=model_line_alphas[j],
                )

            # -----------------------
            # errors relative to 21cmFAST
            # -----------------------
            eps_rel_full = np.full_like(y0, np.nan, dtype=float)
            eps_std_full = np.full_like(y0, np.nan, dtype=float)
            eps_sigma_full = np.full_like(y0, np.nan, dtype=float)

            mask_rel = np.abs(y0) > y_eps
            mask_std = sigma0 > y_eps

            eps_rel_full[mask_rel] = (
                (y1[mask_rel] - y0[mask_rel]) / np.abs(y0[mask_rel])
            )

            eps_std_full[mask_std] = (
                (y1[mask_std] - y0[mask_std]) / sigma0[mask_std]
            )

            eps_sigma_full[mask_std] = (
                sigma1[mask_std] / sigma0[mask_std] - 1.0
            )

            eps_rel_all[j].append(eps_rel_full)
            eps_std_all[j].append(eps_std_full)
            eps_sigma_all[j].append(eps_sigma_full)

    k_vals = k_vals_ref

    # =======================
    # panel 1 formatting
    # =======================
    ax[0].set_xscale("log")
    ax[0].set_yscale("log")
    # ax[0].set_ylim(1.01,10**6) # don't delete this line
    ax[0].set_ylabel(r'$\Delta^2(k)$ [mK$^2$]')
    ax[0].set_title(r"power spectrum of $T_b$")
    ax[0].grid()

    # -----------------------
    # legend for style meaning
    # -----------------------
    h_fast = ax[0].errorbar(
        [np.nan],
        [np.nan],
        yerr=[[0.2], [0.2]],
        fmt='-',
        color='black',
        lw=plot_lw,
        elinewidth=1.2,
        capsize=0,
    )

    style_handles = [h_fast]
    style_labels = ['21cmFAST median ± 1σ']

    for j in range(n_models):
        edgecolor_j, linewidth_j = _edge_kwargs(j)

        style_handles.append({
            'rect_fc': 'black',
            'rect_ec': edgecolor_j,
            'rect_lw': linewidth_j,
            'rect_alpha': model_fill_alphas[j],
            'line_color': 'black',
            'line_ls': model_linestyles[j % len(model_linestyles)],
            'line_lw': plot_lw,
            'line_alpha': model_line_alphas[j],
        })
        style_labels.append(model_labels[j] + ' median ± 1σ')

    legend1 = ax[0].legend(
        style_handles,
        style_labels,
        handler_map={dict: HandlerRectLine()},
        loc='upper left',
        fontsize=9,
        frameon=True,
    )
    ax[0].add_artist(legend1)

    # -----------------------
    # legend for parameter colors
    # -----------------------
    param_handles = [
        Line2D(
            [0], [0],
            color=f"C{i}",
            lw=plot_lw,
            label=labelize(params[i])
        )
        for i in range(num_x_pairs_in_first_panel)
    ]

    ax[0].legend(
        handles=param_handles,
        loc='lower left',
        fontsize=8,
        frameon=True,
    )

    # =======================
    # panels 2--4:
    # median + shaded region over parameter points
    # =======================
    for j in range(n_models):

        color_j = summary_colors[j % len(summary_colors)]
        linestyle_j = model_linestyles[j % len(model_linestyles)]
        edgecolor_j, linewidth_j = _edge_kwargs(j)

        eps_rel_j = np.array(eps_rel_all[j])
        eps_std_j = np.array(eps_std_all[j])
        eps_sigma_j = np.array(eps_sigma_all[j])

        # -----------------------
        # eps_rel
        # -----------------------
        eps_rel_med = np.nanmedian(eps_rel_j, axis=0)
        eps_rel_lo = np.nanpercentile(eps_rel_j, low, axis=0)
        eps_rel_hi = np.nanpercentile(eps_rel_j, high, axis=0)

        valid_rel = (
            np.isfinite(eps_rel_med)
            & np.isfinite(eps_rel_lo)
            & np.isfinite(eps_rel_hi)
        )

        MAE_rel = np.nanmean(np.abs(eps_rel_j))

        ax[1].fill_between(
            k_vals[valid_rel],
            eps_rel_lo[valid_rel],
            eps_rel_hi[valid_rel],
            alpha=model_fill_alphas[j],
            color=color_j,
            edgecolor=edgecolor_j,
            linewidth=linewidth_j,
        )

        ax[1].plot(
            k_vals[valid_rel],
            eps_rel_med[valid_rel],
            color=color_j,
            linestyle=linestyle_j,
            lw=plot_lw,
            alpha=model_line_alphas[j],
        )

        # -----------------------
        # eps_std
        # -----------------------
        eps_std_med = np.nanmedian(eps_std_j, axis=0)
        eps_std_lo = np.nanpercentile(eps_std_j, low, axis=0)
        eps_std_hi = np.nanpercentile(eps_std_j, high, axis=0)

        valid_std = (
            np.isfinite(eps_std_med)
            & np.isfinite(eps_std_lo)
            & np.isfinite(eps_std_hi)
        )

        MAE_std = np.nanmean(np.abs(eps_std_j))

        ax[2].fill_between(
            k_vals[valid_std],
            eps_std_lo[valid_std],
            eps_std_hi[valid_std],
            alpha=model_fill_alphas[j],
            color=color_j,
            edgecolor=edgecolor_j,
            linewidth=linewidth_j,
        )

        ax[2].plot(
            k_vals[valid_std],
            eps_std_med[valid_std],
            color=color_j,
            linestyle=linestyle_j,
            lw=plot_lw,
            alpha=model_line_alphas[j],
        )

        # -----------------------
        # eps_sigma
        # -----------------------
        eps_sigma_med = np.nanmedian(eps_sigma_j, axis=0)
        eps_sigma_lo = np.nanpercentile(eps_sigma_j, low, axis=0)
        eps_sigma_hi = np.nanpercentile(eps_sigma_j, high, axis=0)

        valid_sigma = (
            np.isfinite(eps_sigma_med)
            & np.isfinite(eps_sigma_lo)
            & np.isfinite(eps_sigma_hi)
        )

        MAE_sigma = np.nanmean(np.abs(eps_sigma_j))

        ax[3].fill_between(
            k_vals[valid_sigma],
            eps_sigma_lo[valid_sigma],
            eps_sigma_hi[valid_sigma],
            alpha=model_fill_alphas[j],
            color=color_j,
            edgecolor=edgecolor_j,
            linewidth=linewidth_j,
        )

        ax[3].plot(
            k_vals[valid_sigma],
            eps_sigma_med[valid_sigma],
            color=color_j,
            linestyle=linestyle_j,
            lw=plot_lw,
            alpha=model_line_alphas[j],
        )

    # =======================
    # lower panel formatting
    # =======================
    # ax[1].axhline(0, color="black", linestyle=":", linewidth=1.5)
    # ax[2].axhline(0, color="black", linestyle=":", linewidth=1.5)
    # ax[3].axhline(0, color="black", linestyle=":", linewidth=1.5)

    ax[1].set_xscale("log")
    ax[2].set_xscale("log")
    ax[3].set_xscale("log")

    ax[1].set_ylabel(r"$\epsilon_{\rm rel}$")
    ax[2].set_ylabel(r"$\epsilon_{\rm std}$")
    ax[3].set_ylabel(r"$\epsilon_{\sigma}$")

    ax[3].set_xlabel(r"$k$ [Mpc$^{-1}$]")

    ax[1].grid()
    ax[2].grid()
    ax[3].grid()


    add_lower_legend(
        ax[1],
        eps_rel_all,
        r"$\overline{|\epsilon_{\rm rel}|}$",
        model_labels,
        summary_colors,
        model_linestyles,
        model_fill_alphas,
        model_line_alphas,
        plot_lw,
        edge_kwargs_func=_edge_kwargs,
        fmt=".2f",
        show_handles=False,
    )
    
    add_lower_legend(
        ax[2],
        eps_std_all,
        r"$\overline{|\epsilon_{\rm std}|}$",
        model_labels,
        summary_colors,
        model_linestyles,
        model_fill_alphas,
        model_line_alphas,
        plot_lw,
        edge_kwargs_func=_edge_kwargs,
        fmt=".2f",
        show_handles=False,
    )
    
    add_lower_legend(
        ax[3],
        eps_sigma_all,
        r"$\overline{|\epsilon_{\sigma}|}$",
        model_labels,
        summary_colors,
        model_linestyles,
        model_fill_alphas,
        model_line_alphas,
        plot_lw,
        edge_kwargs_func=_edge_kwargs,
        fmt=".2f",
        show_handles=False,
    )

    ax[1].set_ylim(ymin=-.99, ymax=.99)
    ax[2].set_ylim(ymin=-1.99, ymax=1.99)
    ax[3].set_ylim(ymin=-.49, ymax=.49)

    ax1_sec = ax[1].secondary_xaxis("top")
    ax1_sec.set_xticklabels([])

    ax2_sec = ax[2].secondary_xaxis("top")
    ax2_sec.set_xticklabels([])

    ax3_sec = ax[3].secondary_xaxis("top")
    ax3_sec.set_xticklabels([])

    plt.subplots_adjust(hspace=0)

    if savename is None:
        plt.show()
    else:
        savename = f"power_spectrum_{savename}_z{z_idx}.pdf"
        plt.savefig(savename, bbox_inches="tight")
        print(f"Image saved to {savename}")
        plt.close()

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

def sort_S2_by_l(S2, jthetas, L):

    S2_sorted = np.empty((L, S2.shape[0], S2.shape[1]//L))

    jthetas_sorted = np.empty((L, S2.shape[1]//L, 2, 2))

    num_updated = np.zeros(L, dtype=int)

    for i, jtheta in enumerate(jthetas):

        index = (jtheta[1][1]-jtheta[1][0]) % L

        S2_sorted[index, :, num_updated[index]] = S2[:,i]

        jthetas_sorted[index, num_updated[index]][0] = jtheta[0]

        jthetas_sorted[index, num_updated[index]][1] = jtheta[1]

        num_updated[index] += 1

    S2_sorted = np.array(S2_sorted)

    jthetas_sorted = np.array(jthetas_sorted)

    return S2_sorted, jthetas_sorted

def calculate_sorted_S2(x, S, J, L, jthetas):

    x = x.to(S.filters[0].dtype) if hasattr(S, 'filters') else x.to(torch.float32)

    S_all = np.mean(S(x.to(device))[:,0].cpu().numpy(), axis=(2,3))

    ############################################################

    for j1 in range(J-1):

        for j2 in range(j1+1, J):

            index = [jtheta[0] == (j1,j2) for jtheta in jthetas]

            if (j1,j2) == (0,1):

                S2 = S_all[:,index]

                jthetas_2 = np.array(jthetas[index])

            else:

                S2 = np.concatenate((S2, S_all[:,index]), axis = 1)

                jthetas_2 = np.concatenate([jthetas_2, np.array(jthetas[index])], axis = 0)

    S2_sorted, jthetas_sorted = sort_S2_by_l(S2, jthetas_2, L)

    return S2_sorted, jthetas_sorted

def prepare_x_for_S2(x, z_idx=0, M=64, N=64):

    if x.ndim == 4:
        # [B, 1, 64, 1024] -> [B, 1, 64, 64]
        x = x[..., z_idx:z_idx+N]

    elif x.ndim == 5:
        # [B, 1, 64, 64, 1024] -> [B, 1, 64, 64]
        x = x[..., 0, :, z_idx:z_idx+N]

    else:
        raise ValueError(f"Unsupported x.ndim={x.ndim}, x.shape={x.shape}")

    if x.shape[-2:] != (M, N):
        raise ValueError(
            f"Expected shape (..., {M}, {N}), got {x.shape}. "
            f"Check z_idx={z_idx}, M={M}, N={N}."
        )

    return x

def calculate_reduced_S2(x_pairs, params, J=5, L=4, M=64, N=64, z_idx=0):

    S2_reduced_list = []

    jthetas_reduced_list = []

    for i, (x0, x1) in enumerate(x_pairs):

        x0 = prepare_x_for_S2(x0, z_idx=z_idx, M=M, N=N)
        x1 = prepare_x_for_S2(x1, z_idx=z_idx, M=M, N=N)

        if i == 0:

            S = Scattering2D(J, (M, N), L=L, out_type='list').to(device)

            jthetas = []

            x0 = x0.to(S.filters[0].dtype) if hasattr(S, 'filters') else x0.to(torch.float32)

            for dicts in S(x0.to(device, dtype=S.filters[0].dtype if hasattr(S, 'filters') else torch.float32)):

                jthetas.append([dicts['j'], dicts['theta']])

            jthetas = np.array(jthetas, dtype=object)

            S = Scattering2D(J, (M, N), L=L).to(device)

        S2_reduced_0, jthetas_reduced_0 = calculate_sorted_S2(x0, S, J, L, jthetas)

        S2_reduced_1, jthetas_reduced_1 = calculate_sorted_S2(x1, S, J, L, jthetas)

        S2_reduced_list.append((S2_reduced_0, S2_reduced_1))

        jthetas_reduced_list.append((jthetas_reduced_0, jthetas_reduced_1))

    return S2_reduced_list, jthetas_reduced_list

def average_single_S2_over_l(S2, jthetas, L=4):

    S2_reshape = np.array(np.array_split(S2, S2.shape[2]//L, axis=2))

    jthetas_reshape = np.array(np.array_split(jthetas, jthetas.shape[1]//L, axis=1))

    S2_average = np.average(S2_reshape, axis=3)

    jthetas_average = jthetas_reshape[:,:,0,0,:]

    S2_transpose = S2_average.transpose(2,1,0)

    S2_combine = S2_transpose.reshape(S2_transpose.shape[0], -1)

    j1j2 = jthetas_average.transpose(1,0,2).reshape(-1, 2)

    return S2_combine, j1j2.astype(int)

def average_S2_over_l(x_pairs, params, J, L, M, N, z_idx=0):

    S2_list, jthetas_list = calculate_reduced_S2(x_pairs, params, J, L, M, N, z_idx)

    S2_average = []

    j1j2_average = []

    for i in range(len(S2_list)):

        S2_sim = S2_list[i][0]

        jthetas_sim = jthetas_list[i][0]

        S2_combine_sim, j1j2_sim = average_single_S2_over_l(S2_sim, jthetas_sim, L)

        S2_ml = S2_list[i][1]

        jthetas_ml = jthetas_list[i][1]

        S2_combine_ml, j1j2_ml = average_single_S2_over_l(S2_ml, jthetas_ml, L)

        S2_average.append((S2_combine_sim, S2_combine_ml))

        j1j2_average.append((j1j2_sim, j1j2_ml))

    return np.array(S2_average), np.array(j1j2_average)

# %%
def plot_scattering_transform_2(
    x_pairs,
    params,
    los,
    sigma_level=68.27,
    alpha=0.2,
    J=5,
    L=4,
    M=64,
    N=64,
    savename=None,
    z_idx=0,
    y_eps=0,
    model_labels=None,
    num_x_pairs_in_first_panel=5,
):

    low = (100 - sigma_level) / 2
    high = 100 - low

    fig, ax = plt.subplots(
        4, 1,
        sharex=True,
        figsize=(16, 8),
        dpi=200,
        gridspec_kw=gridspec_kw
    )

    plot_lw = plt.rcParams.get("lines.linewidth", 1.5)

    model_linestyles = [':', '--', '-.', (0, (3, 1, 1, 1, 1, 1))]
    summary_colors = ['grey', 'black', '#8C8C8C', '#9C6B98', '#5F6B6D', '#A89F68']

    # =======================
    # parse model list
    # =======================
    n_models = None
    x_pairs_by_model = None

    for i, (x0, x1) in enumerate(x_pairs):

        x1_list = x1 if isinstance(x1, (list, tuple)) else [x1]

        if n_models is None:
            n_models = len(x1_list)

            if model_labels is None:
                model_labels = [f"model {j}" for j in range(n_models)]

            if len(model_labels) != n_models:
                raise ValueError("model_labels must have the same length as the model list.")

            x_pairs_by_model = [[] for _ in range(n_models)]

        elif len(x1_list) != n_models:
            raise ValueError("Each x_pair must contain the same number of model outputs.")

        for j in range(n_models):
            x_pairs_by_model[j].append((x0, x1_list[j]))

    if n_models == 1:
        model_fill_alphas = [alpha]
        model_line_alphas = [1.0]
    else:
        model_fill_alphas = np.linspace(alpha * 0.65, alpha * 1.35, n_models)
        model_line_alphas = np.linspace(0.6, 1.0, n_models)

    def _use_edge_for_model(j):
        return "2D" in model_labels[j]

    def _edge_kwargs(j):
        if _use_edge_for_model(j):
            return "black", 1
        else:
            return "none", 0

    # =======================
    # compute scattering coefficients for each model
    # =======================
    S2_by_model = []
    j1j2_ref = None

    for j in range(n_models):
        S2_j, j1j2_j = average_S2_over_l(
            x_pairs_by_model[j],
            params,
            J,
            L,
            M,
            N,
            z_idx
        )

        S2_by_model.append(S2_j)

        if j1j2_ref is None:
            j1j2_ref = j1j2_j[0, 0]
        else:
            if not np.array_equal(j1j2_ref, j1j2_j[0, 0]):
                raise ValueError("j1j2 arrays are inconsistent across models.")

    j1j2 = j1j2_ref
    x_coeff = np.arange(j1j2.shape[0])

    eps_rel_all = [[] for _ in range(n_models)]
    eps_std_all = [[] for _ in range(n_models)]
    eps_sigma_all = [[] for _ in range(n_models)]

    # =======================
    # loop over parameter points
    # =======================
    for i in range(len(x_pairs)):

        color_i = f"C{i}"

        # Use the 21cmFAST coefficients from the first model run.
        # They should be identical for all model-specific calls.
        S2_sim = S2_by_model[0][i][0]

        y0 = np.median(S2_sim, axis=0)
        S2_sim_perc = np.percentile(S2_sim, [low, high], axis=0)

        sigma0_lower = y0 - S2_sim_perc[0]
        sigma0_upper = S2_sim_perc[1] - y0
        sigma0 = 0.5 * (S2_sim_perc[1] - S2_sim_perc[0])

        # Top panel: 21cmFAST = solid median + 1 sigma errorbar
        if i < num_x_pairs_in_first_panel:
            ax[0].plot(
                x_coeff,
                y0,
                linestyle='-',
                color=color_i,
                lw=plot_lw,
                alpha=0.95,
            )

            ax[0].errorbar(
                x_coeff,
                y0,
                yerr=[sigma0_lower, sigma0_upper],
                fmt='none',
                color=color_i,
                elinewidth=1.0,
                capsize=0,
                alpha=0.95,
            )

        # -----------------------
        # diffusion models
        # -----------------------
        for j in range(n_models):

            S2_ml = S2_by_model[j][i][1]

            y1 = np.median(S2_ml, axis=0)
            S2_ml_perc = np.percentile(S2_ml, [low, high], axis=0)
            sigma1 = 0.5 * (S2_ml_perc[1] - S2_ml_perc[0])

            linestyle_j = model_linestyles[j % len(model_linestyles)]
            edgecolor_j, linewidth_j = _edge_kwargs(j)

            # Top panel: diffusion = median line + shaded spread
            if i < num_x_pairs_in_first_panel:
                ax[0].fill_between(
                    x_coeff,
                    S2_ml_perc[0],
                    S2_ml_perc[1],
                    color=color_i,
                    alpha=model_fill_alphas[j],
                    edgecolor=edgecolor_j,
                    linewidth=linewidth_j,
                )

                ax[0].plot(
                    x_coeff,
                    y1,
                    linestyle=linestyle_j,
                    color=color_i,
                    lw=plot_lw,
                    alpha=model_line_alphas[j],
                )

            # -----------------------
            # errors relative to 21cmFAST
            # -----------------------
            eps_rel_full = np.full_like(y0, np.nan, dtype=float)
            eps_std_full = np.full_like(y0, np.nan, dtype=float)
            eps_sigma_full = np.full_like(y0, np.nan, dtype=float)

            mask_rel = np.abs(y0) > y_eps
            mask_std = sigma0 > y_eps

            eps_rel_full[mask_rel] = (
                (y1[mask_rel] - y0[mask_rel]) / np.abs(y0[mask_rel])
            )

            eps_std_full[mask_std] = (
                (y1[mask_std] - y0[mask_std]) / sigma0[mask_std]
            )

            eps_sigma_full[mask_std] = (
                sigma1[mask_std] / sigma0[mask_std] - 1.0
            )

            eps_rel_all[j].append(eps_rel_full)
            eps_std_all[j].append(eps_std_full)
            eps_sigma_all[j].append(eps_sigma_full)

    # =======================
    # panel 1 formatting
    # =======================
    ax[0].set_title("reduced scattering coefficients")
    ax[0].set_ylabel(r"$S_2$")
    ax[0].set_yscale("log")
    ax[0].grid()

    # -----------------------
    # legend for style meaning
    # -----------------------
    h_fast = ax[0].errorbar(
        [np.nan],
        [np.nan],
        yerr=[[0.2], [0.2]],
        fmt='-',
        color='black',
        lw=plot_lw,
        elinewidth=1.2,
        capsize=0,
    )

    style_handles = [h_fast]
    style_labels = ['21cmFAST median ± 1σ']

    for j in range(n_models):
        edgecolor_j, linewidth_j = _edge_kwargs(j)

        style_handles.append({
            'rect_fc': 'black',
            'rect_ec': edgecolor_j,
            'rect_lw': linewidth_j,
            'rect_alpha': model_fill_alphas[j],
            'line_color': 'black',
            'line_ls': model_linestyles[j % len(model_linestyles)],
            'line_lw': plot_lw,
            'line_alpha': model_line_alphas[j],
        })
        style_labels.append(model_labels[j] + ' median ± 1σ')

    legend1 = ax[0].legend(
        style_handles,
        style_labels,
        handler_map={dict: HandlerRectLine()},
        loc='upper left',
        fontsize=9,
        frameon=True,
    )
    ax[0].add_artist(legend1)

    # -----------------------
    # legend for parameter colors
    # -----------------------
    param_handles = [
        Line2D(
            [0], [0],
            color=f"C{i}",
            lw=plot_lw,
            label=labelize(params[i])
        )
        for i in range(num_x_pairs_in_first_panel)
    ]

    ax[0].legend(
        handles=param_handles,
        loc='lower left',
        fontsize=8,
        frameon=True,
    )

    # =======================
    # panels 2--4:
    # median + shaded region over parameter points
    # =======================
    for j in range(n_models):

        color_j = summary_colors[j % len(summary_colors)]
        linestyle_j = model_linestyles[j % len(model_linestyles)]
        edgecolor_j, linewidth_j = _edge_kwargs(j)

        eps_rel_j = np.array(eps_rel_all[j])
        eps_std_j = np.array(eps_std_all[j])
        eps_sigma_j = np.array(eps_sigma_all[j])

        # -----------------------
        # eps_rel
        # -----------------------
        eps_rel_med = np.nanmedian(eps_rel_j, axis=0)
        eps_rel_lo = np.nanpercentile(eps_rel_j, low, axis=0)
        eps_rel_hi = np.nanpercentile(eps_rel_j, high, axis=0)

        valid_rel = (
            np.isfinite(eps_rel_med)
            & np.isfinite(eps_rel_lo)
            & np.isfinite(eps_rel_hi)
        )

        ax[1].fill_between(
            x_coeff[valid_rel],
            eps_rel_lo[valid_rel],
            eps_rel_hi[valid_rel],
            alpha=model_fill_alphas[j],
            color=color_j,
            edgecolor=edgecolor_j,
            linewidth=linewidth_j,
        )

        ax[1].plot(
            x_coeff[valid_rel],
            eps_rel_med[valid_rel],
            color=color_j,
            linestyle=linestyle_j,
            lw=plot_lw,
            alpha=model_line_alphas[j],
        )

        # -----------------------
        # eps_std
        # -----------------------
        eps_std_med = np.nanmedian(eps_std_j, axis=0)
        eps_std_lo = np.nanpercentile(eps_std_j, low, axis=0)
        eps_std_hi = np.nanpercentile(eps_std_j, high, axis=0)

        valid_std = (
            np.isfinite(eps_std_med)
            & np.isfinite(eps_std_lo)
            & np.isfinite(eps_std_hi)
        )

        ax[2].fill_between(
            x_coeff[valid_std],
            eps_std_lo[valid_std],
            eps_std_hi[valid_std],
            alpha=model_fill_alphas[j],
            color=color_j,
            edgecolor=edgecolor_j,
            linewidth=linewidth_j,
        )

        ax[2].plot(
            x_coeff[valid_std],
            eps_std_med[valid_std],
            color=color_j,
            linestyle=linestyle_j,
            lw=plot_lw,
            alpha=model_line_alphas[j],
        )

        # -----------------------
        # eps_sigma
        # -----------------------
        eps_sigma_med = np.nanmedian(eps_sigma_j, axis=0)
        eps_sigma_lo = np.nanpercentile(eps_sigma_j, low, axis=0)
        eps_sigma_hi = np.nanpercentile(eps_sigma_j, high, axis=0)

        valid_sigma = (
            np.isfinite(eps_sigma_med)
            & np.isfinite(eps_sigma_lo)
            & np.isfinite(eps_sigma_hi)
        )

        ax[3].fill_between(
            x_coeff[valid_sigma],
            eps_sigma_lo[valid_sigma],
            eps_sigma_hi[valid_sigma],
            alpha=model_fill_alphas[j],
            color=color_j,
            edgecolor=edgecolor_j,
            linewidth=linewidth_j,
        )

        ax[3].plot(
            x_coeff[valid_sigma],
            eps_sigma_med[valid_sigma],
            color=color_j,
            linestyle=linestyle_j,
            lw=plot_lw,
            alpha=model_line_alphas[j],
        )

    # =======================
    # lower panel formatting
    # =======================
    ax[1].set_ylabel(r"$\epsilon_{\rm rel}$")
    ax[2].set_ylabel(r"$\epsilon_{\rm std}$")
    ax[3].set_ylabel(r"$\epsilon_{\sigma}$")

    ax[1].grid()
    ax[2].grid()
    ax[3].grid()

    ax[1].set_ylim(-.49, .49)
    ax[2].set_ylim(-1.99, 1.99)
    ax[3].set_ylim(-.49, .49)

    # vertical separators between l groups
    j1j2_period = j1j2.shape[0] // L
    vline_x = np.arange(
        -0.5,
        j1j2.shape[0] - 0.5 + j1j2_period,
        j1j2_period
    )

    for ax_i in ax:
        ax_i.vlines(
            vline_x,
            ax_i.get_ylim()[0],
            ax_i.get_ylim()[1],
            colors='grey',
            alpha=0.8,
            linestyles=':'
        )


    add_lower_legend(
        ax[1],
        eps_rel_all,
        r"$\overline{|\epsilon_{\rm rel}|}$",
        model_labels,
        summary_colors,
        model_linestyles,
        model_fill_alphas,
        model_line_alphas,
        plot_lw,
        edge_kwargs_func=_edge_kwargs,
        fmt=".2f",
        show_handles=False,
    )
    
    add_lower_legend(
        ax[2],
        eps_std_all,
        r"$\overline{|\epsilon_{\rm std}|}$",
        model_labels,
        summary_colors,
        model_linestyles,
        model_fill_alphas,
        model_line_alphas,
        plot_lw,
        edge_kwargs_func=_edge_kwargs,
        fmt=".2f",
        show_handles=False,
    )
    
    add_lower_legend(
        ax[3],
        eps_sigma_all,
        r"$\overline{|\epsilon_{\sigma}|}$",
        model_labels,
        summary_colors,
        model_linestyles,
        model_fill_alphas,
        model_line_alphas,
        plot_lw,
        edge_kwargs_func=_edge_kwargs,
        fmt=".2f",
        show_handles=False,
    )

    ax1_sec = ax[1].secondary_xaxis('top')
    ax1_sec.set_xticklabels([])

    ax2_sec = ax[2].secondary_xaxis('top')
    ax2_sec.set_xticklabels([])

    ax[3].set_xticks(np.arange(j1j2.shape[0]), j1j2, rotation=90)
    ax[3].set_xlabel(r'$(j_1,\ j_2)$')

    ax3_sec = ax[3].secondary_xaxis('top')
    ax3_sec.set_xticklabels([])

    for i in range(L):
        if i * j1j2_period < ax[3].get_xlim()[1]:
            ax[3].text(
                x=i * j1j2_period,
                y=0.35 + ax[3].get_ylim()[0],
                s=r"$(l_2-l_1)\%L$=" + f"{i}"
            )

    plt.subplots_adjust(hspace=0)

    if savename is None:
        plt.show()
    else:
        savename = f"scattering_coefficients_{savename}_z{z_idx}.pdf"
        plt.savefig(savename, bbox_inches='tight')
        print(f"Image saved to {savename}")
        plt.close()

# %%
import matplotlib.gridspec as gridspec

def plot_Tb_lightcone(x_pairs, params, los, savename=None, num_per_param=1, transform='pt_inv', x_i = 0):

    samples = []
    for i, (x0, x1_list) in enumerate(x_pairs):
        x1 = x1_list[1] # choose 3D case
        if np.shape(x0) != np.shape(x1):
            print(f"{i=}, {np.shape(x0)=} != {np.shape(x1)=}; slicing x1...")
            x1 = x1[:, :, x_i, :, :]
        
        samples.append(np.concatenate([x0[:num_per_param], x1[:num_per_param]], axis=0))
        
    samples = np.concatenate(samples, axis=0)

    print(f"⚠️ plot_Tb_lightcone: samples.shape = {samples.shape}")

    group_size = num_per_param * 2
    n_groups = len(x_pairs)
    row = len(samples)

    # 在每个 group 之间插入一个 gap row
    n_gap = n_groups - 1
    total_rows = row + n_gap

    height_ratios = []
    sample_row_indices = []
    k = 0

    for g in range(n_groups):
        for _ in range(group_size):
            height_ratios.append(1.0)
            sample_row_indices.append(k)
            k += 1
        if g < n_groups - 1:
            height_ratios.append(0.08)  # 控制白色间隔厚度，可调 0.05–0.25

    fig = plt.figure(figsize=(16, 1 * row), dpi=300)
    gs = gridspec.GridSpec(
        total_rows, 1,
        height_ratios=height_ratios,
        hspace=0.0
    )

    axes = []
    sample_i = 0

    distance = los[1]
    redshift = los[0]

    for r in range(total_rows):
        # gap row：留白，不画图
        if height_ratios[r] < 1.0:
            ax_gap = fig.add_subplot(gs[r, 0])
            ax_gap.axis("off")
            continue

        ax = fig.add_subplot(gs[r, 0])
        axes.append(ax)

        i = sample_i
        sample_i += 1

        if samples.ndim == 5:
            data = samples[i, 0, x_i, :, :]
        elif samples.ndim == 4:
            data = samples[i, 0, :, :]

        ny, nx = data.shape

        im = ax.imshow(
            data,
            cmap=cmap,
            vmin=vmin,
            vmax=vmax,
            extent=[distance[0], distance[-1], 0, ny],
            origin='lower',
            aspect='auto'
        )

        ax.set_yticks([])
        ax.set_xticks([])

        group_idx = i // group_size
        row_in_group = i % group_size

        if row_in_group == 0:
            ax.set_ylabel(
                labelize(params[group_idx]),
                fontsize=15,
                va='center',
                ha='right',
                color=f"C{group_idx}",
                labelpad=15
            )

            ax.text(
                0.99, 0.88, '21cmFAST',
                transform=ax.transAxes,
                ha='right',
                va='top',
                fontsize=13,
                fontweight='bold',
                bbox=dict(facecolor='white', alpha=0.8, edgecolor='none', pad=2)
            )

        elif row_in_group == num_per_param:
            ax.text(
                0.99, 0.88, 'diffusion',
                transform=ax.transAxes,
                ha='right',
                va='top',
                fontsize=13,
                fontweight='bold',
                bbox=dict(facecolor='white', alpha=0.8, edgecolor='none', pad=2)
            )

    # bottom x axis
    axes[-1].set_xticks(np.linspace(distance[0], distance[-1], 5))
    axes[-1].set_xticklabels([f"{d/1e3:.1f}" for d in np.linspace(distance[0], distance[-1], 5)])
    axes[-1].tick_params(axis='x', labelsize=15)
    axes[-1].set_xlabel('distance [Gpc]', fontsize=20)

    # top redshift axis
    f_dist2z = interp1d(distance, redshift, kind='linear', fill_value='extrapolate')
    f_z2dist = interp1d(redshift, distance, kind='linear', fill_value='extrapolate')

    ax_twin = axes[0].secondary_xaxis('top', functions=(f_dist2z, f_z2dist))
    ax_twin.set_xlabel('redshift', fontsize=20)
    ax_twin.xaxis.set_major_formatter(matplotlib.ticker.FormatStrFormatter('%.1f'))
    ax_twin.tick_params(axis='x', labelsize=15)

    # colorbar
    if transform != 'pt':
        cbar_ax = fig.add_axes([0.90, 0.128, 0.01, 0.737])
        norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
        cbar = mpl.colorbar.ColorbarBase(cbar_ax, cmap=cmap, norm=norm, orientation='vertical')
        cbar.ax.tick_params(labelsize=15)
        cbar.set_label('Brightness Temperature (mK)', fontsize=20)

    savename = f"Tbs_{savename}.pdf"
    plt.savefig(savename, bbox_inches='tight', dpi=300)
    print(f"Image saved to {savename}")
    plt.show()

# %%
def make_symlog_bins(xmin, xmax, linthresh, n_bins_lin=300, n_bins_log=700):

    lin_bins = np.linspace(-linthresh, linthresh, n_bins_lin)

    pos_log_bins = np.logspace(np.log10(linthresh), np.log10(xmax), n_bins_log//2)

    neg_log_bins = -np.logspace(np.log10(linthresh), np.log10(-xmin), n_bins_log//2)[::-1]

    bins = np.concatenate([neg_log_bins, lin_bins, pos_log_bins])

    return bins

def plot_PDF(x_pairs, params, savename=None, transform='pt_inv'):

    fig, ax = plt.subplots(2, 1, figsize=(8,6), dpi=200, sharex=True, gridspec_kw={'height_ratios': [3,1]})

    plt.subplots_adjust(wspace=0, hspace=-0.001)

    for i, (x0, x1) in enumerate(x_pairs):

        print(f"⚠️ PDF: x0.shape = {x0.shape}, x1.shape = {x1.shape}")

        bins = np.linspace(-5, 5, 1000) if transform == 'pt' else make_symlog_bins(-200, 50, linthresh=1)

        counts_sim, _ = np.histogram(x0, bins=bins, density=True)

        counts_ml, _ = np.histogram(x1, bins=bins, density=True)

        bin_centers = 0.5 * (bins[:-1] + bins[1:])

        print(f"⚠️ PDF: bin_centers.shape = {bin_centers.shape}, counts_sim.shape = {counts_sim.shape}, counts_ml.shape = {counts_ml.shape}")

        ax[0].plot(bin_centers, counts_sim, linestyle=':', color=f"C{i}")

        ax[0].plot(bin_centers, counts_ml, linestyle='-', label=labelize(params[i]), color=f"C{i}")

        ax[1].plot(bin_centers, (counts_ml - counts_sim) / (counts_sim), linestyle='-', color=f"C{i}")

    # === 你已有的 legend 准备部分 ===

    ax1_handles, ax1_labels = ax[0].get_legend_handles_labels()

    legend_line1 = Line2D([0], [0], linestyle=':', color='black')

    legend_line2 = Line2D([0], [0], linestyle='-', color='black')

    legend_elements = [

        legend_line1,

        legend_line2,

        # legend_line3,

    ]

    legend_labels = ['21cmFAST', 'diffusion']

    # === 添加图例 ===

    ax[0].legend(

        legend_elements + ax1_handles,

        legend_labels + ax1_labels,

        handler_map={dict: HandlerRectLine()},  # 替代原来的 tuple handler

        # fontsize=8,

    )

    ax[1].set_xlabel('Brightness Temperature (mK)')

    ax[0].set_ylabel('Probability Density Function')

    ax[1].set_ylabel(r'$\epsilon_{\rm rel}$')

    ax[0].set_yscale('log')#'symlog', linthresh=1e-3)

    if transform != 'pt':

        ax[0].set_xscale('symlog', linthresh=1)

        ax[0].set_ylim(ymin=2e-4, ymax=1e0)

    ax[1].set_ylim(-1.99,ymax=39.99)

    ax[0].grid()

    ax[1].grid()

    ax[1].set_yscale('symlog', linthresh=1)

    plt.savefig(f"PDF_{savename}.pdf", bbox_inches='tight')

    plt.show()

# %%
def plot_Tb_grid(x_pairs, params, los, savename, z_idx, num_per_param=4, transform='pt_inv'):

    samples = []

    for i, (x0, x1) in enumerate(x_pairs):

        samples.append(np.concatenate([x0[:num_per_param], x1[:num_per_param]], axis=0))

    samples = np.concatenate(samples, axis=1)

    samples = samples.swapaxes(0, 1)

    print(f"⚠️ plot_Tb_grid: samples.shape = {samples.shape}")

    row = samples.shape[0]

    col = samples.shape[1]

    fig, axes = plt.subplots(row, col, figsize=(col*4, 4*row), dpi=300)#, constrained_layout=True)

    plt.subplots_adjust(wspace=0, hspace=-0.001)

    distance = los[1]  # 横轴对应物理距离

    redshift = los[0]

    print(f"⚠️ {distance.min()=}, {distance.max()=}, {redshift.min()=}, {redshift.max()=}")

    for i in range(row):

        for j in range(col):

            ax = axes[i,j]

            if samples.ndim == 5:

                # data = samples[i,j,:,:,z_idx]
                data = samples[i,j,0,:,z_idx:z_idx+samples.shape[-2]]

            elif samples.ndim == 4:

                data = samples[i,j,:,z_idx:z_idx+samples.shape[-2]]

            # ny, nx = data.shape

            # imshow 映射索引到物理坐标

            im = ax.imshow(data, cmap=cmap, vmin=vmin, vmax=vmax,

                        origin='lower', aspect='auto')

            ax.set_yticks([])

            ax.set_xticks([])

        # 每组第一个子图加 ylabel

        # group_size = num_per_param * 2

        # if i % group_size == 0:

            # group_idx = i // group_size

        axes[i,0].set_ylabel(

            labelize(params[i]),

            fontsize=18, 

            va='center', 

            ha='center', 

            color=f"C{i}", 

            labelpad=15

            )

    

    for j in range(col):

        ax = axes[0,j]

        ax.set_title('21cmFAST' if j // num_per_param == 0 else 'diffusion', fontsize=20)

    # # 主 x 轴只显示底部最后一个子图

    # axes[-1].set_xticks(np.linspace(distance[0], distance[-1], 5))

    # axes[-1].set_xticklabels([f"{d/1e3:.1f}" for d in np.linspace(distance[0], distance[-1], 5)])

    # axes[-1].set_xlabel('distance [Gpc]', fontsize=20)

    # # 副 x 轴 redshift

    # f_dist2z = interp1d(distance, redshift, kind='linear', fill_value='extrapolate')

    # f_z2dist = interp1d(redshift, distance, kind='linear', fill_value='extrapolate')

    # ax_twin = axes[0].secondary_xaxis('top', functions=(f_dist2z, f_z2dist))

    # ax_twin.set_xlabel('redshift', fontsize=20)

    # ax_twin.xaxis.set_major_formatter(matplotlib.ticker.FormatStrFormatter('%.1f'))

    # colorbar

    if transform != 'pt':

        cbar_ax = fig.add_axes([0.90, 0.128, 0.01, 0.737]) 

        norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)

        cbar = mpl.colorbar.ColorbarBase(cbar_ax, cmap=cmap, norm=norm, orientation='vertical')

        cbar.set_label('Brightness Temperature (mK)', fontsize=20) 

    savename = f"Tbs_grid_{savename}_z{z_idx}.pdf"

    plt.savefig(savename, bbox_inches='tight', dpi=300)

    print(f"Image saved to {savename}")

    # plt.show()

    plt.close()

# %%
def select_steps_logtail(
    n,
    num_frames=120,
    tail_steps=50,
    strength=30.0,
    start_frac=0.0,
    include_first=True,
    include_last=True,
):
    """
    Select denoising steps for video visualization.

    Behavior:
        - early steps: sparse, fast
        - later steps: denser, slower
        - final `tail_steps`: every single denoising step is included

    n:
        total denoising steps, e.g. len(x0_ml_entire)

    num_frames:
        approximate total number of frames to keep.
        Actual number may differ slightly because of np.unique.

    tail_steps:
        force the final `tail_steps` denoising steps to be shown one by one.

    strength:
        controls how aggressively frames concentrate near the end.
        Larger strength -> faster early motion, denser late motion.
        Good values: 10, 20, 30, 50.

    start_frac:
        optionally skip very early denoising steps.
        Usually keep 0.0.
    """

    if n <= 1:
        return np.array([0], dtype=int)

    start = int(round(start_frac * (n - 1)))
    end = n - 1

    tail_steps = min(tail_steps, end - start + 1)
    tail_start = end - tail_steps + 1

    # final tail: show every step
    tail_indices = np.arange(tail_start, end + 1, dtype=int)

    # number of frames for the smooth log-like part
    main_frames = max(num_frames - len(tail_indices), 2)

    # main part covers [start, tail_start - 1]
    main_end = max(start, tail_start - 1)

    if main_end <= start:
        indices = tail_indices
    else:
        u = np.linspace(0.0, 1.0, main_frames)

        # log-like schedule:
        # s(0)=0, s(1)=1
        # derivative is large at beginning, small near the end
        s = np.log1p(strength * u) / np.log1p(strength)

        main_indices = start + np.round(s * (main_end - start)).astype(int)

        indices = np.concatenate([main_indices, tail_indices])

    indices = np.unique(indices)
    indices = indices[(indices >= 0) & (indices < n)]

    if include_first:
        indices = np.unique(np.concatenate([[0], indices]))

    if include_last:
        indices = np.unique(np.concatenate([indices, [n - 1]]))

    return indices.astype(int)

# %%
def evaluate(
    # what2plot: List[str] = ['stack_Tb', 'global_signal', 'power_spectrum', 'scatter_transform'],
    jobIDs: list = [35912978],
    # use_ema: int = 0,
    z_step: int = 1,
    transform: str = 'pt_inv',
    model_labels = ['2D', '3D'],
    ):

    pt_fname = f"../utils/PowerTransformer_25600_z1.pkl"
    print(f"✅ {pt_fname=}; device = {device}")

    save_name = f"{jobIDs}"
    x0_ml = []; x1_ml = []; x2_ml = []; x3_ml = []; x4_ml = []

    for jobID in jobIDs:
        config = f"{jobID}"

        x0_ml.append(load_x_ml(f"Tvir4.400-zeta131.341", config, pt_fname=pt_fname, transform=transform))
        x1_ml.append(load_x_ml(f"Tvir5.477-zeta200.000", config, pt_fname=pt_fname, transform=transform))
        x2_ml.append(load_x_ml(f"Tvir4.699-zeta30.000", config, pt_fname=pt_fname, transform=transform))
        x3_ml.append(load_x_ml(f"Tvir5.600-zeta19.037", config, pt_fname=pt_fname, transform=transform))
        x4_ml.append(load_x_ml(f"Tvir4.800-zeta131.341", config, pt_fname=pt_fname, transform=transform))

        # x0_ml_entire = load_x_ml_entire(f"Tvir4.400-zeta131.341", config, pt_fname=pt_fname, transform=transform)
        # x1_ml_entire = load_x_ml_entire(f"Tvir5.477-zeta200.000", config, pt_fname=pt_fname, transform=transform)
        # x2_ml_entire = load_x_ml_entire(f"Tvir4.699-zeta30.000", config, pt_fname=pt_fname, transform=transform)
    
    print(f"⚠️ x0_ml.shape = {x0_ml[0].shape}")
    dim = x0_ml[0][0,0].ndim 
    if dim == 2:
        num_image, _, HII_DIM, num_redshift = x0_ml[0].shape
    elif dim == 3:
        num_image, _, HII_DIM, _, num_redshift = x0_ml[0].shape

    x0, c0, los = load_h5_as_tensor('LEN128-DIM64-CUB16-Tvir4.4-zeta131.341-0812-104709.h5',num_image=num_image,dim=dim,z_step=z_step,pt_fname=pt_fname, transform=transform)
    x1, c1, los = load_h5_as_tensor('LEN128-DIM64-CUB16-Tvir5.477-zeta200-0812-104013.h5',num_image=num_image,dim=dim,z_step=z_step,pt_fname=pt_fname, transform=transform)
    x2, c2, los = load_h5_as_tensor('LEN128-DIM64-CUB16-Tvir4.699-zeta30-0812-104322.h5',num_image=num_image,dim=dim,z_step=z_step,pt_fname=pt_fname, transform=transform)
    x3, c3, los = load_h5_as_tensor('LEN128-DIM64-CUB16-Tvir5.6-zeta19.037-0625-030227.h5',num_image=num_image,dim=dim,z_step=z_step,pt_fname=pt_fname, transform=transform)
    x4, c4, los = load_h5_as_tensor('LEN128-DIM64-CUB16-Tvir4.8-zeta131.341-0625-030434.h5',num_image=num_image,dim=dim,z_step=z_step,pt_fname=pt_fname, transform=transform)
    
    print(f"⚠️ x0.shape = {x0.shape}")

    x_pairs = [
            (x0, x0_ml),
            (x1, x1_ml),
            (x2, x2_ml),
            (x3, x3_ml),
            (x4, x4_ml),
            ]

    params = [
            c0[0],
            c1[0],
            c2[0],
            c3[0],
            c4[0],
            ]

    # plot_PDF(
    #     x_pairs, 
    #     params, 
    #     savename=save_name,
    #     transform=transform,
    #     )

    plot_Tb_lightcone(
        x_pairs = x_pairs,
        params = params,
        los = los,
        savename = save_name,
        num_per_param = 2,
        transform = transform,
        )

    # # 3D yes; entire no
    # for i in range(HII_DIM):
    #     plot_Tb_lightcone(
    #         x_pairs = x_pairs,
    #         params = params,
    #         los = los,
    #         savename = save_name + f'_x{i:02d}',
    #         num_per_param = 2,
    #         transform = transform,
    #         x_i = i,
    #         )

    # # denoising yes, 3D no.
    # indices = select_steps_logtail(
    #     n=len(x0_ml_entire),
    #     num_frames=130,
    #     tail_steps=60,
    #     strength=30.0,
    # )
    
    # print(f"Selected {len(indices)} frames from {len(x0_ml_entire)} steps")
    # print("First 20:", indices[:20])
    # print("Last 60:", indices[-60:])

    
    # for j, i in enumerate(indices):
    #     print(f"🚀 frame {j+1}/{len(indices)}, step={i}/{len(x0_ml_entire)-1}")
    
    #     plot_Tb_lightcone(
    #         x_pairs=[
    #             (x0[:, :, 0, :, :], x0_ml_entire[i]),
    #             (x1[:, :, 0, :, :], x1_ml_entire[i]),
    #             (x2[:, :, 0, :, :], x2_ml_entire[i]),
    #         ],
    #         params=params,
    #         los=los,
    #         savename=save_name + f"_entire_{j:04d}",
    #         num_per_param=2,
    #         transform=transform,
    #     )

    for z_idx in [512]:
    # for z_idx in tqdm(range(0, num_redshift - HII_DIM + 1, HII_DIM // 16), desc="Processing z slices"):
        plot_global_signal(
            x_pairs=x_pairs,
            params=params,
            los=los,
            savename=save_name,
            z_idx=z_idx,
            model_labels=model_labels,
            # sigma_level=95,
        )
        
        # plot_Tb_grid(
        #         x_pairs = x_pairs,
        #         params = params,
        #         los = los,
        #         savename = save_name,
        #         z_idx=z_idx,
        #         transform = transform,
        # )
        
        plot_power_spectrum(
            x_pairs=x_pairs,
            params=params,
            los=los,
            savename=save_name,
            z_idx=z_idx,
            model_labels=model_labels,
        )
        
        plot_scattering_transform_2(
            x_pairs=x_pairs,
            params=params,
            los=los,
            savename=save_name,
            z_idx=z_idx,
            model_labels=model_labels,
                )

# %%
# colors = plt.cm.get_cmap('Dark2').colors
# plt.rcParams['axes.prop_cycle'] = cycler(color=colors)

# %%
if __name__ == '__main__':
#     sys.argv = ['notebook', '-j', '11111111', '-z', '1', '-t', 'pt_inv']
    # sys.argv = ['notebook', '-j', '48820652', '-z', '1', '-t', 'pt_inv']
#     parser = argparse.ArgumentParser()
#     parser.add_argument("-j", "--jobID", type=str, required=True)
#     parser.add_argument("-z", "--z_step", type=int, default=1)
#     parser.add_argument("-t", "--transform", type=str, default='pt_inv', choices=['pt_inv', 'pt', 'min_max', 'z_score', 'arcsinh'])
#     args = parser.parse_args()
#     print(f"{args.jobID=}")
    evaluate(
        # what2plot = ['stack_Tb', 'global_signal', 'power_spectrum', 'scatter_transform'],
        jobIDs = [55405862, 48820652],
        model_labels=['2D', '3D'],
        # use_ema = 0,
        z_step = 1,
        transform = 'pt_inv',
        )

    # plot_mp4(args.jobID, seconds=16, transform=args.transform)
# Out:
# ✅ pt_fname='../utils/PowerTransformer_25600_z1.pkl'; device = cuda
# fname pattern: Tvir4.400-zeta131.341 55405862 ; len(fnames) = 416 ;
# fnames[0] = Tvir4.400-zeta131.341-device1-model-N800-device_count4-node8-55405862-epoch240-03145530-ema0.npy
# /global/common/software/nersc9/pytorch/2.8.0/lib/python3.12/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.6.1 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %% [markdown]
# ---
